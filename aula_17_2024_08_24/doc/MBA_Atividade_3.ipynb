# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/mrafaelbatista/uniesp_dmie232/main/databases/cursos-prouni-pb-jpa.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   uf_busca              360 non-null    object
#  1   cidade_busca          360 non-null    object
#  2   universidade_nome     360 non-null    object
#  3   campus_nome           360 non-null    object
#  4   nome                  360 non-null    object
#  5   grau                  360 non-null    object
#  6   turno                 360 non-null    object
#  7   mensalidade           360 non-null    float64
#  8   bolsa_integral_cotas  296 non-null    float64
#  9   bolsa_integral_ampla  211 non-null    float64
#  10  bolsa_parcial_cotas   53 non-null     float64
#  11  bolsa_parcial_ampla   53 non-null     float64
#  12  nota_integral_ampla   296 non-null    float64
#  13  nota_integral_cotas   210 non-null    float64
#  14  nota_parcial_ampla    99 non-null     float64
#  15  nota_parcial_cotas    7 non-null      float64
# dtypes: float64(9), object(7)
# memory usage: 45.1+ KB
